# %%
# local에서 연결 시 재시작 전에 'remote-ssh connect to host'에서 ssh구성을 suyeon kim 경로로 선택하고 실행
#%pip install jupyter
#%pip install ipykernel
#%pip install pandas
#%pip install seaborn # terminal에서 또 pip를 해줘야하나?
#%pip install matplotlib # terminal에서 또 pip를 해줘야하나?
#%pip install sklearn

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# col 생략 없이 출력
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('C:/Users/suyeon kim/Downloads/avazu-ctr-prediction/train.csv')
df.head()
# Out:
#              id  click      hour    C1  banner_pos   site_id site_domain  \
# 0  1.000009e+18      0  14102100  1005           0  1fbe01fe    f3845767
# 1  1.000017e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 2  1.000037e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 3  1.000064e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 4  1.000068e+19      0  14102100  1005           1  fe8cc448    9166c161
#
#   site_category    app_id app_domain app_category device_id device_ip  \
# 0      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a  ddd2926e
# 1      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a  96809ac8
# 2      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a  b3cf8def
# 3      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a  e8275b8f
# 4      0569f928  ecad2386   7801e8d9     07d7df22  a99f214a  9644d0bf
#
#   device_model  device_type  device_conn_type    C14  C15  C16   C17  C18  \
# ...

# %%
from sklearn.model_selection import train_test_split

target = 'click'
use_data, not_use_data = train_test_split(df, train_size=0.4, stratify=df[target], random_state=42)

use_data.to_csv('C:/Users/suyeon kim/Downloads/avazu-ctr-prediction/use_train_data.csv', index=False)
not_use_data.to_csv('C:/Users/suyeon kim/Downloads/avazu-ctr-prediction/not_use_train_data.csv', index=False)
